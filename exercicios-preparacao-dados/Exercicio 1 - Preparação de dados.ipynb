# %% [markdown]
# # TAREFA 1 - PREPARAÇÃO DE DADOS
#
# * Nome do aluno: Dgeison Serrão Peixoto
# * Matrícula: 230395
# * E-mail: 1366415@sga.pucminas.br
# * Professor: Victor Sales Silva
# * Disciplina: Preparação, Orquestração e Fluxos Contínuo de dados
# * Atividade: Exercício 1 - Fundamentos da preparação de dados

# %% [markdown]
# IMPORTAÇÃO DAS BIBLIOTECAS

# %%
import pandas as pd

# %% [markdown]
# CARGA DAS BASES / CONJUNTO DE DADOS

# %%
dados = {
    "Cliente": ["joao", "MARIA", "Carlos", "ana", "MARIA ", None],
    "Data_Venda": ["1/5/23", "2023-05-02", "03-05-2023", "2023/05/04", "05.05.2023", "2023-05-06"],
    "Cidade": ["sao paulo", "RIO DE JANEIRO", "belo horizonte", "Sao paulo", "rio  de janeiro", "RiodeJaneiro"],
    "Valor": ["R$150", "200.0", "R$ 175,50", "300", "duzentos", "250"],
    "Produto": ["Celular", "CELULAR", "Notebook", "NOTEBOOK", "Celular", "celular"]
}

# Criando o DataFrame
df = pd.DataFrame(dados)

# Exibindo o datraframe
df.head()
# Out:
#   Cliente  Data_Venda           Cidade      Valor   Produto
# 0    joao      1/5/23        sao paulo      R$150   Celular
# 1   MARIA  2023-05-02   RIO DE JANEIRO      200.0   CELULAR
# 2  Carlos  03-05-2023   belo horizonte  R$ 175,50  Notebook
# 3     ana  2023/05/04        Sao paulo        300  NOTEBOOK
# 4  MARIA   05.05.2023  rio  de janeiro   duzentos   Celular

# %% [markdown]
# ## EXERCÍCIO

# %% [markdown]
# ### 1. Leia os arquivos e realize os tratamentos solicitados
# * Corrija letras maiúsculas/minúsculas
# * Elimine espaços em branco extras
# * Remova registros sem nome

# %% [markdown]
# ### 2. Uniformize as datas de venda
# * Transforme todas para o formato YYYY-MM-DD

# %% [markdown]
# ### 3. Padronize os nomes das cidades:
#
# * Ajuste capitalização
# * Corrija variações e erros de digitação
#   - Ex: "sao paulo", "Sao paulo" → "São Paulo"

# %% [markdown]
# ### 4. Limpe e converta a coluna Valor:
#
# * Remova símbolos (R$, vírgulas)
# * Converta para tipo float
# * Trate valores não numéricos, como "duzentos"

# %% [markdown]
# ### 5. Padronize os nomes dos produtos
# * Capitalize corretamente: "Celular", "Notebook"

# %% [markdown]
# ### 6. Exiba o resultado dos tratamentos
