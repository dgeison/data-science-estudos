# %% [markdown]
# -------------------------------------------------------------------------
# *   PONTIFÍCIA UNIVERSIDADE CATÓLICA DE MINAS GERAIS
# *   PROFESSOR: VICTOR SALES SILVA
# *   ALUNO: **<INSERIR CÓDIGO DE PESSOA OU MATRÍCULA>***
# *   ATIVIDADE: EXEMPLO DE LEITURA DE ARQUIVO EM FORMATO JSON UTILIZANDO PANDAS
# -------------------------------------------------------------------------

# %% [markdown]
# # IMPORTAÇÃO DAS BIBLIOTECAS

# %%
import pandas as pd

# %% [markdown]
# # DEFINIÇÃO DAS VARIÁVEIS

# %%
url_arquivo = 'https://stgaccount687878.blob.core.windows.net/datalake-687878/bronze/DADOS_ESTUDANTES/DADOS_ESTUDANTES.json'
arquivo = 'DADOS_ESTUDANTES.json'

options = {
    "enconding":"Latin1",
    "multiline":"true"
}

# %% [markdown]
# # LEITURA DO ARQUIVO JSON USANDO PANDAS

# %%
# Lê o conteúdo do arquivo JSON
try:
  with open(arquivo, "r", encoding="UTF-8") as file:
      json_content = file.read()
except UnicodeDecodeError:
  with open(arquivo, "r", encoding="Latin-1") as file:
      json_content = file.read()

# Remove as quebras de linha (\n)
json_content = json_content.replace("\n", "")

# Cria um dataframe Pandas com o conteúdo dos dados
df = pd.read_json(json_content)

# %% [markdown]
# # EXIBINDO OS METADADOS (SCHEMA) DO ARQUIVO

# %%
df.head(5)

# %% [markdown]
# # EXIBINDO OS METADADOS (SCHEMA) DO ARQUIVO

# %%
df.info()

# %% [markdown]
# # AJUSTAR O SCHEMA DOS DADOS, SE NECESSÁRIO
