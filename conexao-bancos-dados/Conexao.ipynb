# %%
# !pip install databricks-sql-connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.9/133.9 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.1 MB/s eta 0:00:00
# ...
#   Created wheel for thrift: filename=thrift-0.20.0-cp311-cp311-linux_x86_64.whl size=420369 sha256=08aedaa74bebcf95b516ba58e6e6c73e555aa97ce3565b44671fb2e4d6423e31
#   Stored in directory: /root/.cache/pip/wheels/e2/bc/11/b3431cfbf4afeb954480926b2f46fdc56082b8b234d6d4208b
# Successfully built thrift
# ...

# %%
import pandas as pd
from databricks import sql

# Conexão (como antes)
connection = sql.connect(
  server_hostname='dbc-7d8c43ca-0abd.cloud.databricks.com',
  http_path='/sql/1.0/warehouses/d962b8a737b3c78f',
  access_token='SEU_DATABRICKS_TOKEN_AQUI'
)

# Executa a consulta
query = "SELECT * FROM default.carros"
df = pd.read_sql(query, connection)

# Mostra o DataFrame
df.head()
# Out:
# /tmp/ipython-input-1678951631.py:13: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)
#    Consumo  Cilindros  Cilindradas  RelEixoTraseiro  Peso  Tempo  TipoMotor  \
# 0       21          6          160               39   262   1646          0
# 1       21          6          160               39  2875   1702          0
# 2      228          4          108              385   232   1861          1
# 3      214          6          258              308  3215   1944          1
# 4      187          8          360              315   344   1702          0
#
#    Transmissao  Marchas  Carburadors   HP
# 0            1        4            4  110
# 1            1        4            4  110
# 2            1        4            1   93
# 3            0        3            1  110
# ...

# %%
connection.close()
